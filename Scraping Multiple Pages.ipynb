# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import lxml

# %% [markdown]
# # Carpages.ca

# %%
url = "https://www.carpages.ca/used-cars/search/?category_id=2"

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--
#                                 ______________
#                         __..=='|'   |         ``-._
#            \=====_..--'/'''    |    |              ``-._
#            |'''''      ```---..|____|_______________[)>.``-.._____
#            |\_______.....__________|____________     ''  \      __````---.._
#          ./'     /.-'_'_`-.\       |  ' '       ```````---|---/.-'_'_`=.-.__```-._
#          |.__  .'/ /     \ \`.      \                     | .'/ /     \ \`. ```-- `.
#           \  ``|| |   o   | ||-------\-------------------/--|| |   o   | ||--------|
#            "`--' \ \ _ _ / / |______________________________| \ \ _ _ / / |..----```
#                   `-.....-'                                    `-.....-'
#
#                ______
#               / ____/___ __________  ____ _____ ____  _____ _________ _
#              / /   / __ `/ ___/ __ \/ __ `/ __ `/ _ \/ ___// ___/ __ `/
#             / /___/ /_/ / /  / /_/ / /_/ / /_/ /  __(__  )/ /__/ /_/ /
#             \____/\__,_/_/  / .___/\__,_/\__, /\___/____(_)___/\__,_/
#                            /_/          /____/
# --><!--[if lt IE 7]>
# <html class="no-js lt-ie9 lt-ie8 lt-ie7 env-prod">
# <![endif]--><!--[if IE 7]>
# <html class="no-js lt-ie9 lt-ie8 env-prod">
# <![endif]--><!--[if IE 8]>
# <html class="no-js lt-ie9 env-prod">
# <![endif]--><!--[if gt IE 8]><!--><html class="no-js env-prod">
# <!--<![endif]-->
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <script type="text/javascript">
#         document.documentElement.className = document.documentElement.className.replace('no-js', 'yes-js')
#         window.CP = {
#             DATA: {
#                 BACK: {}, FRONT: {}
#             }, _queuedJS: []
#         }
#
#         CP.Queue = function (k) {
#             return function (j) {
#                 k.push(j)
#             }
#         }
#
#         CP.queue = new CP.Queue(CP._queuedJS)
#     </script>
# <title>
#             New and Used Coupes for Sale | Carpages.ca        </title>
# <!-- Meta Tags -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1, user-scalable=0" name="viewport"/>
# <meta content="app-id=616927030" name="apple-itunes-app"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="New and Used Coupes for Sale" name="title"/>
# <meta content="Browse New and Used New and Used Coupes for Sale for sale. Carpages.ca features thousands of used vehicles for sale throughout Canada." name="description"/>
# <meta content="index, follow" name="robots"/>
# <meta content="en" name="language"/>
# <meta content="app-id=616927030" name="apple-itunes-app"/>
# <link href="https://www.carpages.ca/rss/recently_listed/" rel="alternate" title="Recently Listed Used Vehicles" type="application/rss+xml"/> <meta content="https://www.carpages.ca/images/primary/logo/oglogo.jpg" property="og:image"/>
# <meta content="New and Used Coupes for Sale" property="og:title"/>
# <meta content="Find a new or used vehicle on Carpages.ca. Start your search now!" property="og:description"/>
# <meta content="https://www.carpages.ca/used-cars/search/?category_id=2" property="og:url"/>
# <meta content="Carpages.ca" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@carpages" name="twitter:site"/>
# <meta content="Carpages.ca" name="twitter:domain"/>
# <meta content="Carpages.ca" name="twitter:app:name:iphone"/>
# <meta content="Carpages.ca" name="twitter:app:name:ipad"/>
# <meta content="id616927030" name="twitter:app:id:iphone"/>
# <meta content="id616927030" name="twitter:app:id:ipad"/>
# <meta content="Carpages.ca" name="twitter:app:name:googleplay"/>
# <meta content="ca.carpages.carpagesconsumer" name="twitter:app:id:googleplay"/>
# <!-- End Meta Tags -->
# <!-- Stylesheets -->
# <link href="/css/primary/style.css?v=20220321" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/dist/css/bs-grid.css?v=20220321" media="screen" rel="stylesheet" type="text/css"/>
# <!-- End Stylesheets -->
# <!-- Favicons -->
# <link href="https://www.carpages.ca/dist/images/logo/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/manifest.json" rel="manifest"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="#FFFFFF" name="theme-color"/>
# <meta content="Carpages.ca" name="application-name"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="Carpages.ca" name="apple-mobile-web-app-title"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/coast-228x228.png" rel="icon" sizes="228x228" type="image/png"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/favicon-230x230.png" rel="icon" sizes="230x230" type="image/png"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/favicon.ico" rel="shortcut icon"/>
# <meta content="#FFFFFF" name="msapplication-TileColor"/>
# <meta content="https://www.carpages.ca/dist/images/logo/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="https://www.carpages.ca/dist/images/logo/favicons/browserconfig.xml" name="msapplication-config"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/yandex-browser-manifest.json" rel="yandex-tableau-widget"/>
# <meta content="https://www.carpages.ca/dist/images/logo/favicons/twitter.png" property="twitter:image"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-startup-image-320x460.png" media="(device-width: 320px) and (device-height: 480px) and (-webkit-device-pixel-ratio: 1)" rel="apple-touch-startup-image"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-startup-image-640x920.png" media="(device-width: 320px) and (device-height: 480px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-startup-image-640x1096.png" media="(device-width: 320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-startup-image-750x1294.png" media="(device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-startup-image-1182x2208.png" media="(device-width: 414px) and (device-height: 736px) and (orientation: landscape) and (-webkit-device-pixel-ratio: 3)" rel="apple-touch-startup-image"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-startup-image-1242x2148.png" media="(device-width: 414px) and (device-height: 736px) and (orientation: portrait) and (-webkit-device-pixel-ratio: 3)" rel="apple-touch-startup-image"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-startup-image-748x1024.png" media="(device-width: 768px) and (device-height: 1024px) and (orientation: landscape) and (-webkit-device-pixel-ratio: 1)" rel="apple-touch-startup-image"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-startup-image-768x1004.png" media="(device-width: 768px) and (device-height: 1024px) and (orientation: portrait) and (-webkit-device-pixel-ratio: 1)" rel="apple-touch-startup-image"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-startup-image-1496x2048.png" media="(device-width: 768px) and (device-height: 1024px) and (orientation: landscape) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
# <link href="https://www.carpages.ca/dist/images/logo/favicons/apple-touch-startup-image-1536x2008.png" media="(device-width: 768px) and (device-height: 1024px) and (orientation: portrait) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
# <!-- End Favicons -->
# <!-- Ad Init --><!-- Ad Setup -->
# <script>
#             var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#
#             (function() {
#                 var gads = document.createElement( 'script' );
#                 gads.async = true;
#
#                 var useSSL = "https:" === document.location.protocol;
#                 gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
#
#                 var node = document.getElementsByTagName( "script" )[ 0 ];
#                 node.parentNode.insertBefore( gads, node );
#             })();
#
#             var adSlots = {};
#             var dynAdSlots = {};
#             var sizeMappings = {};
#
#             // Function to find if an ad slot contains a blank pixel.
#             function blankPixelExists(adPlacementDiv) {
#                 var iframe = adPlacementDiv.getElementsByTagName("iframe")[0];
#                 if ( ! iframe) {
#                     return false;
#                 }
#                 var jcpblankpixelEle = iframe.contentWindow.document.getElementsByClassName("jcpblankpixel");
#                 return !!jcpblankpixelEle.length;
#             }
#
#             function hiddenIframe(adPlacementDiv) {
#                 return adPlacementDiv.querySelector( "div[id*='__container__'] iframe[id*='__hidden__']" );
#             }
#
#             // Function to hide the corresponding ad component if an ad placement returns empty/blank
#             function collapseEmptyAdComponents( slotElementID, options ) {
#                 var event = options.event || {};
#                 var adPlacementDiv = document.getElementById( slotElementID );
#
#                 if (( event.isEmpty || blankPixelExists( adPlacementDiv ) || hiddenIframe( adPlacementDiv ) )) {
#                       if ( slotElementID.includes( "sugg-selling" )) {
#                           adPlacementDiv.parentElement.style.display = "none";
#                       } else {
#                           adPlacementDiv.style.display = "none";
#                       }
#                 } else {
#                     adPlacementDiv.style.minHeight = event.size[1] + "px";
#                 }
#             }
#
#             // Function to handle wrapping ad slot in ratio based wrapper if needed.
#             function handleRatioBasedAds( slotElementID, options ) {
#                 var event = options.event || {};
#                 var adHeights1x1 = [ 300, 301, 303 ];
#
#                 // Get the ad container's CSS ID
# 	            var adPlacementDiv = document.getElementById( slotElementID );
# 	            var adPlacementParent = adPlacementDiv.parentElement;
# 	            var adSize = event.size || [ 0, 0 ];
#
# 	            if ( blankPixelExists( adPlacementDiv )) {
# 	                return;
# 	            }
#
# 	            if ( slotElementID.indexOf( "adAdhesion" ) > -1 || slotElementID.indexOf( "mob" ) > -1 ) {
# 	                // console.log( "Ad:", { slotElementID, adSize });
#
#                     var flexAdContainer = document.createElement( "div" );
#                     flexAdContainer.classList.add("iab-flexad");
#
#                     var flexAdSizer = document.createElement( "div" );
#                     flexAdSizer.classList.add("iab-flexsizer");
#
#                     var flexAdContentContainer = document.createElement( "div" );
#                     flexAdContentContainer.classList.add("iab-adcontent");
#
#                     flexAdContainer.appendChild( flexAdSizer );
#                     flexAdContainer.appendChild( flexAdContentContainer );
#
#                     // 1x1 ratio based ad
#                     if (adSize[0] === 300 && adHeights1x1.indexOf( adSize[1] ) > -1 ) {
#                         // console.log( "1x1", { adPlacementParent });
#
#                         flexAdSizer.classList.add("flex-1x1");
#
#                         adPlacementParent.parentNode.replaceChild( flexAdContainer, adPlacementParent );
#                         flexAdContentContainer.appendChild( adPlacementParent );
#                     }
#
#                     // 4x1 ratio based ad
#                     if ( adSize[0] === 320 && adSize[1] === 80 ) {
#                         // console.log( "4x1", { adPlacementParent });
#
#                         flexAdSizer.classList.add("flex-mob-4x1");
#
#                         adPlacementParent.parentNode.replaceChild( flexAdContainer, adPlacementParent );
#                         flexAdContentContainer.appendChild( adPlacementParent );
#                     }
# 	            }
#             }
#
#             googletag.cmd.push( function() {
#                 googletag.pubads().collapseEmptyDivs( true );
#                 googletag.pubads().setCentering( true );
#
#                 // Event Listener for when ads load and display
#                 googletag.pubads().addEventListener("slotRenderEnded", function( event ) {
#
#                     var slotID = event.slot.getSlotId();
#                     var slotElementID = event.slot.getSlotElementId();
#
#                     collapseEmptyAdComponents( slotElementID, { event: event, slotID: slotID });
#                     handleRatioBasedAds( slotElementID, { event: event, slotID: slotID });
#
#                     // Check for slot element ID - adAdhesion
#                     if (slotElementID === "adAdhesion") {
#                         // Adjust your content to allow for the unit
#                         // to be in a fixed position at the bottom of the viewport
#                         // For example, add padding to your footer the same height as the ad being rendered
#                         // Show Close Button after 5 seconds
#                         setTimeout(
#                             function() {
#                                 // Example structure and dynamic creation - style should be in main style sheet
#                                 // <button id="jam-adhesion-ad-close-button" class="jam-adhesion-ad-close" type="button">Close</button>
#                                 var adAdhesionCloseButtonId = "jam-adhesion-ad-close-button";
#
#                                 if ( !!document.getElementById( adAdhesionCloseButtonId )) {
#                                   return;
#                                 }
#
#                                 var adhesionContainer = document.querySelector(".jam-adhesion-ad");
#                                 var adAdhesionContainer = document.getElementById( "adAdhesion" );
#                                 var jam_adAdhesionContainer = document.getElementById( "jam_adAdhesion" );
#                                 var adAdhesionCloseButton = document.createElement( "button" );
#
#                                 adAdhesionCloseButton.id = adAdhesionCloseButtonId;
#                                 adAdhesionCloseButton.className = "jam-adhesion-ad-close";
#                                 adAdhesionCloseButton.setAttribute( "type","button" );
#                                 adAdhesionCloseButton.style.display = "block";
#                                 adAdhesionCloseButton.innerHTML = "Close";
#
#                                 adAdhesionCloseButton.addEventListener( "click", function() {
#                                   adhesionContainer.classList.add( "hidden" );
#                                   adAdhesionContainer.classList.add( "hidden" );
#                                   jam_adAdhesionContainer.classList.add( "hidden") ;
#                                 });
#
#                                 adhesionContainer.appendChild( adAdhesionCloseButton );
#                             },
#                             5000
#                         );
#                     }
#                 });
#             });
#         </script><script>
#             function adUnitFromWindowSize(adUnit, windowWidth) {
#               return windowWidth < 480 ? adUnit.replace("dfp", "mob") : adUnit;
#             }
#
#             var jagFirstLevel = adUnitFromWindowSize("jam.cpg.used.dfp", window.innerWidth);
#             var jagSecondLevel = "lssrp";
#             var jagThirdLevel = "ct";
#
#             var jagYr = "2020";
#             var jagMak = "";
#             var jagMod = "";
#             var jagType = "coupe";
#             var jagStyle = "";
#             var jagFuel = "";
#             var jagContent = "";
#             var jagProd = "listings";
#             var jagSubProd = "srp";
#             var jagPub = "cpg";
#             var jagTemplate = "srp"
#             var jagTest = ""; // NEEDS TO BE SET TO BLANK WHEN IN PRODUCTION
#
#
#             function adUnitForVars() {
#                 var rtn = "";
#
#                 if (jagSecondLevel) {
#                     rtn += "/" + jagSecondLevel;
#                 }
#
#                 if (jagThirdLevel) {
#                     rtn += "/" + jagThirdLevel;
#                 }
#
#                 return rtn;
#             }
#
#             window.jamData = {
#                 sitename: location.hostname,
#                 site: adUnitFromWindowSize(jagFirstLevel, window.innerWidth),
#                 adunit: adUnitForVars(),
#                 prod: jagProd,
#                 subprod: jagSubProd,
#                 year: jagYr,
#                 make: jagMak,
#                 model: jagMod,
#                 type: jagType,
#                 style: jagStyle,
#                 fuel: jagFuel,
#                 content: jagContent,
#                 pubtemplate: jagTemplate,
#                 pub: jagPub
#             };
#         </script>
# <script>
#     googletag.cmd.push( function() {
#         // Leaderboard Size Mapping ------------------------------
#
#             sizeMappings.mapping728x90 = googletag.sizeMapping()
#                 .addSize([480, 320], [728,90])
#                 .addSize([0, 0], [])
#                 .build();
#
#             sizeMappings.mapping728x91 = googletag.sizeMapping()
#                 .addSize([480, 320], [[728,91],[728,90]])
#                 .addSize([0, 0], [])
#                 .build();
#
#             sizeMappings.mapping728flex = googletag.sizeMapping()
#                 .addSize([480, 320], [[728,90],[970,250]])
#                 .addSize([0, 0], [])
#                 .build();
#
#             // -------------------------------------------------------
#
#
#
#
#             // Brand Spotlight Size Mapping --------------------------
#
#             sizeMappings.mapping300x120 = googletag.sizeMapping()
#                 .addSize([480, 320], [300,120])
#                 .addSize([0, 0], [])
#                 .build();
#
#             // -------------------------------------------------------
#
#
#
#
#             // Medium Rectangle Size Mapping -------------------------
#
#             sizeMappings.mapping300x250 = googletag.sizeMapping()
#                 .addSize([480, 320], [300,250])
#                 .addSize([0, 0], [])
#                 .build();
#
#             sizeMappings.mapping300x251 = googletag.sizeMapping()
#                 .addSize([480, 320], [[300,251],[300,250]])
#                 .addSize([0, 0], [])
#                 .build();
#
#             sizeMappings.mapping300x252 = googletag.sizeMapping()
#                 .addSize([480, 320], [300,252])
#                 .addSize([0, 0], [])
#                 .build();
#
#             sizeMappings.mapping300x253 = googletag.sizeMapping()
#                 .addSize([480, 320], [300,253])
#                 .addSize([0, 0], [])
#                 .build();
#
#             sizeMappings.mapping300x250flex = googletag.sizeMapping()
#                 .addSize([799, 320], [[300,250],[300,600]])
#                 .addSize([480, 320], [300,250])
#                 .addSize([0, 0], [])
#                 .build();
#
#             sizeMappings.mapping300x253flex = googletag.sizeMapping()
#                 .addSize([799, 320], [[300,253],[300,603],[300,250],[300,600]])
#                 .addSize([480, 320], [300,253])
#                 .addSize([0, 0], [])
#                 .build();
#
#             // -------------------------------------------------------
#
#
#
#
#             // Suggestive Selling Desktop Size Mapping ---------------
#
#             sizeMappings.mappingSuggSellDesktop = googletag.sizeMapping()
#                 .addSize([0, 0], [])
#                 .addSize([480, 320], [643,247])
#                 .build();
#
#             sizeMappings.mappingSuggSellMobile = googletag.sizeMapping()
#                 .addSize([480, 320], [])
#                 .addSize([0, 0], [[320,50],[300,250],[300,300],[375,233]])
#                 .build();
#
#             // -------------------------------------------------------
#
#
#
#
#             // Shopping Link Size Mapping ----------------------------
#
#             sizeMappings.mapping400 = googletag.sizeMapping()
#                 .addSize([0, 0], [])
#                 .addSize([480, 320], [400,40])
#                 .build();
#
#             // -------------------------------------------------------
#
#
#
#
#             // Mobile Size Mapping -----------------------------------
#
#             sizeMappings.mappingMobile250 = googletag.sizeMapping()
#                 .addSize([480, 320], [])
#                 .addSize([0, 0], [[320,50],[300,250],[300,300]])
#                 .build();
#
#             sizeMappings.mappingMobile251 = googletag.sizeMapping()
#                 .addSize([480, 320], [])
#                 .addSize([0, 0], [[320,51],[300,251],[320,50],[300,250],[300,300],[300,301]])
#                 .build();
#
#             sizeMappings.mappingMobile253 = googletag.sizeMapping()
#                 .addSize([480, 320], [])
#                 .addSize([0, 0], [[320,53],[300,253],[320,50],[300,250],[300,300],[300,303]])
#                 .build();
#
#             sizeMappings.mappingMobileAdhesion = googletag.sizeMapping()
#                 .addSize([480, 320], [])
#                 .addSize([0, 0], [[320,50],[320,54],[320,75],[320,80]])
#                 .build();
#
#             sizeMappings.mappingMobilePhotoBox = googletag.sizeMapping()
#                 .addSize([480, 320], [])
#                 .addSize([0, 0], [[320,50],[320,54],[320,75],[320,80],[300,250],[300,300]])
#                 .build();
#
#             // -------------------------------------------------------
#             adSlots["jam_ad-leaderboard-top"] = googletag.defineSlot("/36117602,1040773/jam.cpg.used.dfp/lssrp/ct", [728,90], "jam_ad-leaderboard-top").defineSizeMapping(sizeMappings.mapping728x90).setTargeting("slot", "dt-wide-top").addService(googletag.pubads());
# adSlots["jam_ad-mob-top251"] = googletag.defineSlot("/36117602,1040773/jam.cpg.used.mob/lssrp/ct", [[320,51],[300,251],[320,50],[300,250],[300,300],[300,301]], "jam_ad-mob-top251").defineSizeMapping(sizeMappings.mappingMobile251).setTargeting("slot", "m-box-2").addService(googletag.pubads());
# adSlots["jam_adAdhesion"] = googletag.defineSlot("/36117602,1040773/jam.cpg.used.mob/lssrp/ct", [[320,50],[320,54],[320,75],[320,80]], "jam_adAdhesion").defineSizeMapping(sizeMappings.mappingMobileAdhesion).setSafeFrameConfig({ allowPushExpansion: true }).setTargeting("slot", "m-adhesion").addService(googletag.pubads());
#
# googletag.pubads().setTargeting('yr', '2020');
# googletag.pubads().setTargeting('mak', '');
# googletag.pubads().setTargeting('mod', '');
# googletag.pubads().setTargeting('type', 'coupe');
# googletag.pubads().setTargeting('style', '');
# googletag.pubads().setTargeting('fuel', '');
# googletag.pubads().setTargeting('content', '');
# googletag.pubads().setTargeting('prod', 'listings');
# googletag.pubads().setTargeting('subprod', 'srp');
# googletag.pubads().setTargeting('pub', 'cpg');
# googletag.pubads().setTargeting('pubtemplate', 'srp');googletag.pubads().enableSingleRequest();
# googletag.pubads().enableAsyncRendering();
# googletag.enableServices();
#     googletag.pubads().addEventListener("slotRenderEnded", function(event) {
#         if (event.isEmpty) {
#             const adElement = document.getElementById(event.slot.getSlotElementId());
#             if (adElement) {
#                 adElement.style.display = "none";
#                 adElement.parentNode.style.display = "none";
#             }
#         }
#     });    } );
# </script>
# <!-- End Ad Setup -->
# <!-- End Ad Init -->
# </head>
# <body class="body-container used">
# <script>
#   // Initialize data layer array
#   var gtmDataLayer = [];
#
#   // GTM Slot Data
#   gtmDataLayer.push([]);
# </script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-WBC7" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl+'';f.parentNode.insertBefore(j,f);
# })(window,document,'script','gtmDataLayer','GTM-WBC7');</script>
# <!-- End Google Tag Manager -->
# <!-- Criteo Page Data -->
# <script>
#     function getSiteType() {
#         var isMobile = window.matchMedia("only screen and (max-width: 400px)");
#         var isTablet = window.matchMedia("only screen and (min-width: 401px) and (max-width: 769px)");
#
#         if (isMobile.matches) {
#             return 'm';
#         } else if (isTablet.matches) {
#             return 't';
#         }
#
#         return 'd';
#     }
#
#     // Add criteo page data to gtmDataLayer
#     gtmDataLayer.push({"PageType":"ListingPage","email":"","products":[8814380,8814005,8813915]});
#
#     // Push site_type to gtmDataLayer
#     gtmDataLayer.push({
#         'site_type': getSiteType()
#     })
# </script>
# <!-- End Criteo Page Data -->
# <!-- LD JSON -->
# <script data-rh="true" type="application/ld+json">
#     {"@context":"https:\/\/schema.org","@type":["Product","Car"],"name":"Cars","offers":[{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/ontario\/scarborough\/2006-acura-rsx-8814380\/","itemOffered":"2006 Acura RSX Type-S\/ ONE OWNER \/ 6SPD\/ RARE FIND \/ MAINTAINED \/","itemCondition":null,"priceCurrency":"CAD","price":9500},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/british-columbia\/surrey\/2020-ford-mustang-8814005\/","itemOffered":"2020 Ford Mustang EcoBoost Fastback  - Aluminum Wheels","itemCondition":null,"priceCurrency":"CAD","price":41999},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/ontario\/mississauga\/2011-volkswagen-golf-8813915\/","itemOffered":"2011 Volkswagen Golf 3dr HB Auto","itemCondition":null,"priceCurrency":"CAD","price":5200},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/ontario\/toronto\/2017-toyota-corolla-8813753\/","itemOffered":"2017 Toyota Corolla ","itemCondition":null,"priceCurrency":"CAD","price":20699},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/ontario\/north-york\/2014-nissan-gt-r-8813402\/","itemOffered":"2014 Nissan GT-R PREMIUM BEST COLOUR COMBO","itemCondition":null,"priceCurrency":"CAD","price":103888},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/saskatchewan\/regina\/2013-chevrolet-camaro-8812916\/","itemOffered":"2013 Chevrolet Camaro 2SS","itemCondition":null,"priceCurrency":"CAD","price":35998},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/british-columbia\/vancouver\/1999-ferrari-360-8812304\/","itemOffered":"1999 Ferrari 360 Modena F1","itemCondition":null,"priceCurrency":"CAD","price":99980},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/british-columbia\/vancouver\/2009-jaguar-xk-8812295\/","itemOffered":"2009 Jaguar XK XKR Coupe","itemCondition":null,"priceCurrency":"CAD","price":39980},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/ontario\/waterloo\/2014-scion-fr-s-8812229\/","itemOffered":"2014 Scion FR-S 2DR CPE MAN | BLUETOOTH | BACKUP CAM","itemCondition":null,"priceCurrency":"CAD","price":17956},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/ontario\/vaughan\/2015-mercedes-benz-c-class-8812112\/","itemOffered":"2015 Mercedes-Benz C-Class C63 AMG COUPE I 507 EDITION I COMING SOON","itemCondition":null,"priceCurrency":"CAD","price":58910},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/ontario\/waterdown\/2017-volkswagen-golf-8812088\/","itemOffered":"2017 Volkswagen Golf Highline","itemCondition":null,"priceCurrency":"CAD","price":23999},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/ontario\/cambridge\/2011-audi-a5-8811485\/","itemOffered":"2011 Audi A5 2.0L Premium\/AWD\/NO ACCIDENTS\/SAFETY INCLUDED","itemCondition":null,"priceCurrency":"CAD","price":12490},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/ontario\/london\/2015-chevrolet-corvette-8811419\/","itemOffered":"2015 Chevrolet Corvette Z51 2LT","itemCondition":null,"priceCurrency":"CAD","price":74995},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/british-columbia\/langley\/2010-chevrolet-camaro-8811410\/","itemOffered":"2010 Chevrolet Camaro 2SS Coupe * 6 Speed Manual, Sunroof, Nav*","itemCondition":null,"priceCurrency":"CAD","price":35995},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/ontario\/toronto\/2018-mercedes-benz-c-class-8809301\/","itemOffered":"2018 Mercedes-Benz C-Class AMG C43 4MATIC Coupe, NAV, CAM, BURMESTER","itemCondition":null,"priceCurrency":"CAD","price":55800},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/ontario\/sarnia\/2013-subaru-brz-8808953\/","itemOffered":"2013 Subaru BRZ Sport-tech","itemCondition":null,"priceCurrency":"CAD","price":16995},{"@type":"Offer","url":"https:\/\/www.carpages.ca\/used-cars\/ontario\/brantford\/2013-dodge-challenger-8808809\/","itemOffered":"2013 Dodge Challenger R\/T | 6 SPEED M\/T |SUPER TRACK PKG| ROOF |O ...
# <!--[if lt IE 10]>
# <div class="no-support">
#     <img src="/images/primary/logo/logo.jpg" alt="Carpages.ca Logo" />
#     <h1 class="brand-face kilo">You're using an outdated browser</h1>
#     <p class="gamma grey">Please <a href="http://browsehappy.com/">upgrade your browser</a> to view this website.</p>
#     <p class="delta"><a href="/account/login/">Sign in to Dealer Dashboard
#         &raquo;</a></p>
# </div>
# <![endif]-->
# <div class="gg-header-pad"></div>
# <header class="w-gg-header box rule rule--brand rule--medium push-none">
# <div class="container">
# <div class="row soft-sides">
# <div class="col-12">
# <div class="gg-header">
# <a class="gg-header__logo" href="/" id="js-xmas-logo">
# <div class="fit-img">
# <img alt="Carpages.ca" src="/dist/images/logo/svg/logo-wordmark.svg"/>
# </div>
# </a>
# <div class="gg-header__menu-icon">
# <a class="button button--clear button--outline" data-link="nonav" id="js-menu-button">
# <i class="button-menu__icon"></i> Menu
#                         </a>
# </div>
# <div class="gg-header__cover" id="js-main-nav-cover"></div>
# <div class="gg-header__nav" id="js-main-nav">
# <ul class="primary-nav">
# <li class="flyout flyout--center flyout--large">
# <a class="nav-link" data-link="nonav" href="/"><span>Buy A Vehicle</span>
# <span class="svg"><svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M8.71 11.71l2.59 2.59c.39.39 1.02.39 1.41 0l2.59-2.59c.63-.63.18-1.71-.71-1.71H9.41c-.89 0-1.33 1.08-.7 1.71z"></path></svg></span></a>
# <div class="flyout__content epsilon">
# <div class="box box--shadow-lg round-double flush soft">
# <h6 class="push-half--bottom">Browse by Body Style</h6>
# <ul class="multi-list multi-list--vertical multi-list--medium-3">
# <li><a href="/used-cars/search/?category_id=1&amp;ref=nav">Convertible</a></li><li><a href="/used-cars/search/?category_id=2&amp;ref=nav">Coupe</a></li><li><a href="/used-cars/search/?category_id=3&amp;ref=nav">Hatchback</a></li><li><a href="/used-cars/search/?category_id=4&amp;ref=nav">Minivan / Van</a></li><li><a href="/used-cars/search/?category_id=5&amp;ref=nav">Sedan</a></li><li><a href="/used-cars/search/?category_id=6&amp;ref=nav">SUV / Crossover</a></li><li><a href="/used-cars/search/?category_id=7&amp;ref=nav">Pickup Truck</a></li><li><a href="/used-cars/search/?category_id=8&amp;ref=nav">Wagon</a></li><li><a href="/used-cars/search/?category_id=15&amp;ref=nav">Wheelchair Accessible</a></li><li><a href="/used-cars/search/?category_id=11&amp;ref=nav">Motorcycle</a></li><li><a href="/used-cars/search/?category_id=10&amp;ref=nav">Commercial</a></li> </ul>
# <h6 class="push-half--bottom">Browse by Make</h6>
# <ul class="multi-list multi-list--vertical multi-list--medium-3">
# <li><a href="/used-cars/acura/?ref=nav">Acura</a></li><li><a href="/used-cars/alfa-romeo/?ref=nav">Alfa Romeo</a></li><li><a href="/used-cars/aston-martin/?ref=nav">Aston Martin</a></li><li><a href="/used-cars/audi/?ref=nav">Audi</a></li><li><a href="/used-cars/bmw/?ref=nav">BMW</a></li><li><a href="/used-cars/bentley/?ref=nav">Bentley</a></li><li><a href="/used-cars/buick/?ref=nav">Buick</a></li><li><a href="/used-cars/cadillac/?ref=nav">Cadillac</a></li><li><a href="/used-cars/chevrolet/?ref=nav">Chevrolet</a></li><li><a href="/used-cars/chrysler/?ref=nav">Chrysler</a></li><li><a href="/used-cars/dodge/?ref=nav">Dodge</a></li><li><a href="/used-cars/ducati/?ref=nav">Ducati</a></li><li><a href="/used-cars/ferrari/?ref=nav">Ferrari</a></li><li><a href="/used-cars/fiat/?ref=nav">Fiat</a></li><li><a href="/used-cars/ford/?ref=nav">Ford</a></li><li><a href="/used-cars/gmc/?ref=nav">GMC</a></li><li><a href="/used-cars/harley-davidson/?ref=nav">Harley-Davidson</a></li><li><a href="/used-cars/honda/?ref=nav">Honda</a></li><li><a href="/used-cars/hyundai/?ref=nav">Hyundai</a></li><li><a href="/used-cars/infiniti/?ref=nav">Infiniti</a></li><li><a href="/used-cars/international/?ref=nav">International</a></li><li><a href="/used-cars/jaguar/?ref=nav">Jaguar</a></li><li><a href="/used-cars/jeep/?ref=nav">Jeep</a></li><li><a href="/used-cars/kia/?ref=nav">Kia</a></li><li><a href="/used-cars/lamborghini/?ref=nav">Lamborghini</a></li><li><a href="/used-cars/land-rover/?ref=nav">Land Rover</a></li><li><a href="/used-cars/lexus/?ref=nav">Lexus</a></li><li><a href="/used-cars/lincoln/?ref=nav">Lincoln</a></li><li><a href="/used-cars/lotus/?ref=nav">Lotus</a></li><li><a href="/used-cars/mini/?ref=nav">MINI</a></li><li><a href="/used-cars/maserati/?ref=nav">Maserati</a></li><li><a href="/used-cars/maybach/?ref=nav">Maybach</a></li><li><a href="/used-cars/mazda/?ref=nav">Mazda</a></li><li><a href="/used-cars/mercedes-benz/?ref=nav">Mercedes-Benz</a></li><li><a href="/used-cars/mitsubishi/?ref=nav">Mitsubishi</a></li><li><a href="/used-cars/nissan/?ref=nav">Nissan</a></li><li><a href="/used-cars/pontiac/?ref=nav">Pontiac</a></li><li><a href="/used-cars/porsche/?ref=nav">Porsche</a></li><li><a href="/used-cars/ram/?ref=nav">RAM</a></li><li><a href="/used-cars/rolls-royce/?ref=nav">Rolls-Royce</a></li><li><a href="/used-cars/scion/?ref=nav">Scion</a></li><li><a href="/used-cars/smart/?ref=nav">Smart</a></li><li><a href="/used-cars/subaru/?ref=nav">Subaru</a></li><li><a href="/used-cars/tesla/?ref=nav">Tesla</a></li><li><a href="/used-cars/toyota/?ref=nav">Toyota</a></li><li><a href="/used-cars/volkswagen/?ref=nav">Volkswagen</a></li><li><a href="/used-cars/volvo/?ref=nav">Volvo</a></li> </ul>
# </div>
# </div>
# </li>
# <li>
# <a class="nav-link" href="/dealer/">Find A Dealer</a> </li>
# <li>
# <a class="nav-link" href="/insurance/">Get Insurance</a> </li>
# <li>
# <a class="nav-link" href="/financing/">Get Financing</a> </li>
# </ul>
# <div class="flyout flyout--right flyout--medium mobile-layout" data-layout="regular">
# <a class="button button--link nav-icon-link button--circle" data-link="nonav" href="/account/" rel="nofollow">
# <span class="svg"><svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M12 12c2.21 0 4-1.79 4-4s-1.79-4-4-4-4 1.79-4 4 1.79 4 4 4zm0 2c-2.67 0-8 1.34-8 4v1c0 .55.45 1 1 1h14c.55 0 1-.45 1-1v-1c0-2.66-5.33-4-8-4z"></path></svg></span>
# <span class="accessibility">Account</span> </a>
# <div class="flyout__content">
# <div class="box box--shadow-lg round-double soft-half flush">
# <a class="button button--brand full align--center" href="/account/login/" rel="nofollow">Sign In</a> </div>
# </div>
# </div>
# <div data-layout="compact">
# <a class="button button--brand button--medium full align--center" href="/account/login/" rel="nofollow">Sign In</a> </div>
# </div><!-- / gg-header__nav -->
# <div class="w-gg-header__search">
# <div class="gg-header__search" id="js-main-search">
# <a class="button button--link nav-icon-link fixed-size" data-link="nonav" href="#" id="js-search-button" rel="nofollow" tabindex="-1">
# <span class="svg"><svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M15.5 14h-.79l-.28-.27c1.2-1.4 1.82-3.31 1.48-5.34-.47-2.78-2.79-5-5.59-5.34-4.23-.52-7.79 3.04-7.27 7.27.34 2.8 2.56 5.12 5.34 5.59 2.03.34 3.94-.28 5.34-1.48l.27.28v.79l4.25 4.25c.41.41 1.08.41 1.49 0 .41-.41.41-1.08 0-1.49L15.5 14zm-6 0C7.01 14 5 11.99 5 9.5S7.01 5 9.5 5 14 7.01 14 9.5 11.99 14 9.5 14z"></path></svg></span> </a>
# <form action="/search/site/">
# <input class="text-input text-input--simple no-shadow" id="js-search-input" name="q" placeholder="Search for a vehicle or dealer..." tabindex="-1" type="text"/>
# </form>
# <a class="button button--link nav-icon-link fixed-size" data-link="nonav" href="#" id="js-search-close-button" rel="nofollow" tabindex="-1">
# <span class="svg"><svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M18.3 5.71c-.39-.39-1.02-.39-1.41 0L12 10.59 7.11 5.7c-.39-.39-1.02-.39-1.41 0-.39.39-.39 1.02 0 1.41L10.59 12 5.7 16.89c-.39.39-.39 1.02 0 1.41.39.39 1.02.39 1.41 0L12 13.41l4.89 4.89c.39.39 1.02.39 1.41 0 .39-.39.39-1.02 0-1.41L13.41 12l4.89-4.89c.38-.38.38-1.02 0-1.4z"></path></svg></span> </a>
# </div><!-- / gg-header__search -->
# </div><!-- / w-gg-header__search -->
# </div>
# </div>
# </div>
# </div>
# </header>
# <!-- Feature Section -->
# <!-- End Feature Section -->
# <!-- Main Section -->
# <div class="main-container">
# <div class="l-row fx fd-c fd-r--large">
# <div class="l-column lg:l-column-4 xl:l-column-3 fx fd-c as-s--large push-none">
# <div class="box bleed-half bleed-none--large filter-widget-container">
# <div class="accordian accordian--expand accordian--medium soft--sides filter-widget">
# <h3 class="accordian__title text-align-center push-none soft--ends">Filter Results</h3>
# <div class="accordian__content srp-filters">
# <!--  SEARCH FORM -->
# <form action="/used-cars/search/" class="fx fd-c form--left-label" id="main_search_form" method="post">
# <hr class="rule bleed flush-bottom"/>
# <fieldset class="form__fields soft-ends">
# <div class="form__fields__label">
# <span>Sale Type</span>
# </div>
# <div class="checkbox-group push-half-top">
# <label class="checkbox fg align-center">
# <input checked="checked" class="checkbox__control js-reset__default" id="sale_type_new" name="sale_type[]" type="checkbox" value="new"/> <div class="checkbox__content" data-off="○" data-on="✓">New</div>
# </label>
# <label class="checkbox fg align-center">
# <input checked="checked" class="checkbox__control js-reset__default" id="sale_type_used" name="sale_type[]" type="checkbox" value="used"/> <div class="checkbox__content" data-off="○" data-on="✓">Used</div>
# </label>
# </div>
# </fieldset>
# <hr class="rule bleed flush-bottom"/>
# <fieldset class="checkbox-group--vertical form__fields accordian accordian--disclosure is-active">
# <div class="form__fields__label accordian__title fx jc-sb ai-c">
# <span>Buy From Home</span>
# <span class="tag tag--brand tag--milli push-auto-left push-right">NEW</span>
# <span class="accordian__icon"></span>
# </div>
# <div class="accordian__content">
# <div class="checkbox-custom full" style="
#                         --customURL: url(/images/primary/buyFromHome/bfh_logo_brand.svg);
#                         --customOFFURL: url(/images/primary/buyFromHome/bfh_logo_light_grey.svg);
#                         ">
# <input class="checkbox-custom__control" id="has_buy_from_home" name="has_buy_from_home" type="checkbox" value="1"/>
# <div class="checkbox-custom__label">
# <label class="fx fd-r ai-c jc-sb" for="has_buy_from_home">
# <span>Only show Buy From Home</span>
# <span class="checkbox-custom__content empty"></span>
# </label>
# </div>
# </div>
# </div>
# </fieldset>
# <hr class="rule bleed flush-bottom"/>
# <fieldset class="form__fields accordian accordian--disclosure is-active">
# <label class="form__fields__label accordian__title fx fd-r jc-sb" for="keyword">
# <span>Keyword Search</span>
# <span class="accordian__icon"></span>
# </label>
# <div class="accordian__content">
# <div class="input-group">
# <input autocomplete="off" class="text-input full" id="keyword" name="keyword" placeholder='Try "diesel" or "blue sedan"' type="text" value=""/> </div>
# </div>
# </fieldset>
# <hr class="rule bleed flush-bottom"/>
# <!--  LOCATION -->
# <fieldset class="form__fields accordian accordian--disclosure is-active" id="locationAccordianControl">
# <label class="form__fields__label accordian__title fx jc-sb">
# <span class="text-ellipsis">Location</span>
# <span class="accordian__icon"></span>
# </label>
# <div class="accordian__content">
# <div class="fx fd-c ai-s">
# <fieldset class="visible--js push-none">
# <div class="js-location-finder" data-init="false" id="js-search-location-finder">
# <span class="text-button-group">
# <div class="flyout flyout--simple flyout--linger full">
# <input autocomplete="off" class="text-input full" name="locationField" placeholder="All of Canada" type="text" value=""/>
# </div>
# <button class="button button--white js-tooltip tooltip--white round button--find-me push-half-left" data-tip="Find Me!" type="button">
# <i class="icon--target"></i>
# <div class="spinner spinner--classic">
# <svg enable-background="new 156 -189 512 512" version="1.1" viewbox="156 -189 512 512" x="0" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0">
# <path d="M547.8 157.5l45.2 45.2c12.5 12.5 12.5 32.8 0 45.2 -12.5 12.5-32.8 12.5-45.2 0l-45.2-45.2c-12.5-12.5-12.5-32.8 0-45.2S535.2 145 547.8 157.5z"></path>
# <path d="M412 323c-17.7 0-32-14.3-32-32v-64c0-17.7 14.3-32 32-32s32 14.3 32 32v64C444 308.7 429.7 323 412 323z"></path>
# <path d="M276.2 248c-12.5 12.5-32.8 12.5-45.2 0 -12.5-12.5-12.5-32.8 0-45.2l45.2-45.2c12.5-12.5 32.8-12.5 45.2 0s12.5 32.8 0 45.2L276.2 248z"></path>
# <path d="M284 67c0 17.7-14.3 32-32 32h-64c-17.7 0-32-14.3-32-32s14.3-32 32-32h64C269.7 35 284 49.3 284 67z"></path>
# <path d="M276.2-23.5L231-68.8c-12.5-12.5-12.5-32.8 0-45.2s32.8-12.5 45.2 0l45.2 45.2c12.5 12.5 12.5 32.8 0 45.2S288.8-11 276.2-23.5z"></path>
# <path d="M412-61c-17.7 0-32-14.3-32-32v-64c0-17.7 14.3-32 32-32s32 14.3 32 32v64C444-75.3 429.7-61 412-61z"></path>
# <path d="M547.8-23.5C535.2-11 515-11 502.5-23.5s-12.5-32.8 0-45.2l45.2-45.2c12.5-12.5 32.8-12.5 45.2 0s12.5 32.8 0 45.2L547.8-23.5z"></path>
# <path d="M636 99h-64c-17.7 0-32-14.3-32-32s14.3-32 32-32h64c17.7 0 32 14.3 32 32S653.7 99 636 99z"></path>
# </svg>
# </div>
# </button>
# </span>
# <div class="js-location-finder hidden" data-init="false">
# <input disabled="disabled" id="province_code" name="province_code" type="hidden" value=""/><input disabled="disabled" id="city" name="city" type="hidden" value=""/><input disabled="disabled" id="ll" name="ll" type="hidden" value=""/></div> </div>
# </fieldset>
# <noscript>
# <fieldset class="field">
# <input class="text-input" name="location" placeholder="All of Canada" type="text" value=""/>
# </fieldset>
# </noscript>
# <fieldset class="form__fields as-fs push-half-top muted" id="js-radius">
# <div class="select-group">
# <span>Within</span>
# <div class="select"><select disabled="disabled" id="search_radius" name="search_radius"><option value="25">25</option>
# <option value="50">50</option>
# <option selected="selected" value="100">100</option>
# <option value="250">250</option>
# <option value="500">500</option>
# </select></div> <span>KM</span>
# </div>
# </fieldset>
# </div>
# </div>
# </fieldset>
# <hr class="rule bleed flush-bottom"/>
# <!--  SEARCH FILTERS -->
# <fieldset class="form__fields accordian accordian--disclosure is-active">
# <label class="form__fields__label accordian__title fx jc-sb">
# <span>Category</span>
# <span class="accordian__icon"></span>
# </label>
# <div class="accordian__content">
# <script>
#                     CP.DATA.categories = {
#                         roots: JSON.parse('[{"id":10,"name":"Commercial","value":"10|57|58|59|61|62|73|75|76|79|86"},{"id":11,"name":"Motorcycle","value":"11|21|22|23|24|25|26|27|28|29"},{"id":12,"name":"RV","value":"12|33|34|35|36|37|38|39|40|42"},{"id":13,"name":"Boat","value":"13|18|49|50|52|54"},{"id":14,"name":"Trailer","value":"14|44|45|46|48|80|82|83|84|88"},{"id":17,"name":"Snowmobile","value":"17"},{"id":19,"name":"Equipment","value":"19|65|68"},{"id":20,"name":"Passenger Vehicle","value":"20|15|1|2|3|4|5|6|7|8|9"},{"id":30,"name":"Off-road","value":"30|16|31"}]'),
# ...
# <path d="M28.6 2L13.72 19.0454L9.4 15.6371H7L13.72 27L31 2H28.6Z"></path>
# </svg>
# </span> </div>
# <div class="bfh_srp_widget__right fx fx-col">
# <div class="grow fx ai-c soft-half--sides">
# <span>Buy From Home Options</span>
# </div>
# <div class="grow fx ai-c jc-sa soft-half--sides border-t border-bfh">
# <span class="svg svg-sm"><svg enable-background="new 0 0 24 24" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><g><rect fill="none" height="24" width="24"></rect></g><g><g><path d="M15,16l-4,4h8c1.1,0,2-0.9,2-2v0c0-1.1-0.9-2-2-2H15z"></path><path d="M12.06,7.19l-8.77,8.77C3.11,16.14,3,16.4,3,16.66V19c0,0.55,0.45,1,1,1h2.34c0.27,0,0.52-0.11,0.71-0.29l8.77-8.77 L12.06,7.19z"></path><path d="M18.71,8.04c0.39-0.39,0.39-1.02,0-1.41l-2.34-2.34c-0.39-0.39-1.02-0.39-1.41,0l-1.83,1.83l3.75,3.75L18.71,8.04z"></path></g></g></svg></span><span class="svg svg-sm"><svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0V0z" fill="none"></path><path d="M19.5 8H17V6c0-1.1-.9-2-2-2H3c-1.1 0-2 .9-2 2v9c0 1.1.9 2 2 2 0 1.66 1.34 3 3 3s3-1.34 3-3h6c0 1.66 1.34 3 3 3s3-1.34 3-3h1c.55 0 1-.45 1-1v-3.33c0-.43-.14-.85-.4-1.2L20.3 8.4c-.19-.25-.49-.4-.8-.4zM6 18c-.55 0-1-.45-1-1s.45-1 1-1 1 .45 1 1-.45 1-1 1zm13.5-8.5l1.96 2.5H17V9.5h2.5zM18 18c-.55 0-1-.45-1-1s.45-1 1-1 1 .45 1 1-.45 1-1 1z"></path></svg></span> </div>
# </div>
# </a>
# </hgroup>
# </div>
# </div>
# </div>
# </div>
# <!-- END ACTUAL RESULTS -->
# <!-- End Search Results List -->
# <!-- Search Results Pagination -->
# <div class="rule--top box no-shadow">
# <ul class="pagination pagination--center"><li><span>1</span></li><li><a href="/used-cars/search/?num_results=50&amp;category_id=2&amp;p=2">2</a></li><li><a href="/used-cars/search/?num_results=50&amp;category_id=2&amp;p=3">3</a></li><li><a href="/used-cars/search/?num_results=50&amp;category_id=2&amp;p=4">4</a></li><li><a href="/used-cars/search/?num_results=50&amp;category_id=2&amp;p=5">5</a></li><li><a href="/used-cars/search/?num_results=50&amp;category_id=2&amp;p=6">6</a></li><li><a href="/used-cars/search/?num_results=50&amp;category_id=2&amp;p=7">7</a></li><li><a class="nextprev" href="/used-cars/search/?num_results=50&amp;category_id=2&amp;p=2" title="Next Page">→</a></li></ul></div>
# <!-- End Search Results Pagination -->
# <!-- End Search Results-->
# </div>
# <div class="hidden--large">
# <div class="ad-slot no-header ad-size--300x250">
# <div class="ad dynamic-ad dynamic-ad-proximity-load" data-ad-device="mobile" data-ad-height="253" data-ad-placeholder="ad-mobile-bottom" data-ad-type="dynamic:flex253" data-ad-width="300" id="jam_ad-mobile-bottom"></div></div> </div>
# </div>
# </div>
# <script>
#                 var globallyAccessibleNamespace = window.globallyAccessibleNamespace || {};
#                 window.globallyAccessibleNamespace = globallyAccessibleNamespace;
#
#                 // Next Slot Name Generator
#                 var nextSlotId = 1;
#                 function generateNextSlotName() {
#                     var id = nextSlotId++;
#                     return "dynAd" + id;
#                 }
#
#                 function generateSlotDiv(divId, width) {
#                     var slotDiv = document.createElement("div");
#                     slotDiv.id = divId + "-Ad";
#                     slotDiv.style.width = width + "px";
#                     slotDiv.style.backgroundColor = "#FFF";
#                     document.getElementById(divId).appendChild(slotDiv);
#                 }
#
#                 // Function to add content to page, mimics real infinite scroll
#                 // but keeps it much simpler from a code perspective.
#                 globallyAccessibleNamespace.addDynamicAd = function(divId, width, height, device) {
#                     var slotName = divId;
#
#                     width = parseInt(width);
#                     height = parseInt(height);
#
#                     // Create a div for the slot
#                     generateSlotDiv("jam_" + divId, width);
#
#                     // Define the slot itself, call display() to
#                     // register the div and refresh() to fetch ad.
#                     googletag.cmd.push(function() {
#                         try {
#                 if (device === "desktop") {
#
#         dynAdSlots["jam_" + slotName] = googletag.defineSlot(
#                 "/36117602,1040773/jam.cpg.used.dfp/lssrp/ct",
#                 [[728,91],[728,90]],
#                 "jam_" + divId
#             )
#             .setTargeting("slot", "dt-wide-breaker")
#             .defineSizeMapping( sizeMappings.mapping728x91 )
#             .addService(googletag.pubads());
#
#                 } else if (device === "mobile") {
#
#         dynAdSlots["jam_" + slotName] = googletag.defineSlot(
#                 "/36117602,1040773/jam.cpg.used.mob/lssrp/ct",
#                 [[320,53],[300,253],[320,50],[300,250],[300,300],[300,303]],
#                 "jam_" + divId
#             )
#             .setTargeting("slot", "m-breaker")
#             .defineSizeMapping( sizeMappings.mappingMobile253 )
#             .addService(googletag.pubads());
#
#                 }
#
#                 // Display has to be called before
#                 // refresh and after the slot div is in the page.
#                 googletag.display("jam_" + divId);
#             } catch (error) {
#                 //console.log("DynamicAd - Error:", { slotName, divId, error });
#             }
#                     });
#                 };
#
#                 globallyAccessibleNamespace.addDynamicAd251 = function(divId, width, height, device) {
#                     var slotName = divId;
#
#                     width = parseInt(width);
#                     height = parseInt(height);
#
#                     // Create a div for the slot
#                     generateSlotDiv("jam_" + divId, width);
#
#                     // Define the slot itself, call display() to
#                     // register the div and refresh() to fetch ad.
#                     googletag.cmd.push(function() {
#                         try {
#                 if (device === "desktop") {
#
#         dynAdSlots["jam_" + slotName] = googletag.defineSlot(
#                 "/36117602,1040773/jam.cpg.used.dfp/lssrp/ct",
#                 [[300,251],[300,250]],
#                 "jam_" + divId
#             )
#             .setTargeting("slot", "dt-box-2")
#             .defineSizeMapping( sizeMappings.mapping300x251 )
#             .addService(googletag.pubads());
#
#                 } else if (device === "mobile") {
#
#         dynAdSlots["jam_" + slotName] = googletag.defineSlot(
#                 "/36117602,1040773/jam.cpg.used.mob/lssrp/ct",
#                 [[320,51],[300,251],[320,50],[300,250],[300,300],[300,301]],
#                 "jam_" + divId
#             )
#             .setTargeting("slot", "m-box-2")
#             .defineSizeMapping( sizeMappings.mappingMobile251 )
#             .addService(googletag.pubads());
#
#                 }
#
#                 // Display has to be called before
#                 // refresh and after the slot div is in the page.
#                 googletag.display("jam_" + divId);
#             } catch (error) {
#                 //console.log("DynamicAd - Error:", { slotName, divId, error });
#             }
#                     });
#                 };
#
#                 globallyAccessibleNamespace.addDynamicAdFlex250 = function(divId, width, height, device) {
#                     var slotName = divId;
#
#                     width = parseInt(width);
#                     height = parseInt(height);
#
#                     // Create a div for the slot
#                     generateSlotDiv("jam_" + divId, width);
#
#                     // Define the slot itself, call display() to
#                     // register the div and refresh() to fetch ad.
#                     googletag.cmd.push(function() {
#                         try {
#                 if (device === "desktop") {
#
#         dynAdSlots["jam_" + slotName] = googletag.defineSlot(
#                 "/36117602,1040773/jam.cpg.used.dfp/lssrp/ct",
#                 [[300,250],[300,600]],
#                 "jam_" + divId
#             )
#             .setTargeting("slot", "dt-box-1")
#             .defineSizeMapping( sizeMappings.mapping300x250flex )
#             .addService(googletag.pubads());
#
#                 } else if (device === "mobile") {
#
#         dynAdSlots["jam_" + slotName] = googletag.defineSlot(
#                 "/36117602,1040773/jam.cpg.used.mob/lssrp/ct",
#                 [[320,50],[300,250],[300,300]],
#                 "jam_" + divId
#             )
#             .setTargeting("slot", "m-box-1")
#             .defineSizeMapping( sizeMappings.mappingMobile250 )
#             .addService(googletag.pubads());
#
#                 }
#
#                 // Display has to be called before
#                 // refresh and after the slot div is in the page.
#                 googletag.display("jam_" + divId);
#             } catch (error) {
#                 //console.log("DynamicAd - Error:", { slotName, divId, error });
#             }
#                     });
#                 };
#
#                 globallyAccessibleNamespace.addDynamicAdFlex253 = function(divId, width, height, device) {
#                     var slotName = divId;
#
#                     width = parseInt(width);
#                     height = parseInt(height);
#
#                     // Create a div for the slot
#                     generateSlotDiv("jam_" + divId, width);
#
#                     // Define the slot itself, call display() to
#                     // register the div and refresh() to fetch ad.
#                     googletag.cmd.push(function() {
#                         try {
#                 if (device === "desktop") {
#
#         dynAdSlots["jam_" + slotName] = googletag.defineSlot(
#                 "/36117602,1040773/jam.cpg.used.dfp/lssrp/ct",
#                 [[300,253],[300,603],[300,250],[300,600]],
#                 "jam_" + divId
#             )
#             .setTargeting("slot", "dt-box-breaker")
#             .defineSizeMapping( sizeMappings.mapping300x253flex )
#             .addService(googletag.pubads());
#
#                 } else if (device === "mobile") {
#
#         dynAdSlots["jam_" + slotName] = googletag.defineSlot(
#                 "/36117602,1040773/jam.cpg.used.mob/lssrp/ct",
#                 [[320,53],[300,253],[320,50],[300,250],[300,300],[300,303]],
#                 "jam_" + divId
#             )
#             .setTargeting("slot", "m-breaker")
#             .defineSizeMapping( sizeMappings.mappingMobile253 )
#             .addService(googletag.pubads());
#
#                 }
#
#                 // Display has to be called before
#                 // refresh and after the slot div is in the page.
#                 googletag.display("jam_" + divId);
#             } catch (error) {
#                 //console.log("DynamicAd - Error:", { slotName, divId, error });
#             }
#                     });
#                 };
#             </script>
# </div>
# <!-- End Main Section -->
# <!-- Main Footer -->
# <footer class="box--dark rule--top rule--brand rule--large soft--ends hidden--print">
# <div class="container">
# <div class="row soft footer-nav">
# <div class="col-12 col-lg-6">
# <div class="row">
# <div class="col-12 col-md-4">
# <h6 class="brand-face push-half--bottom">Shopping Tools</h6>
# <ul class="list--no-style push-none">
# <li><a href="/">Find a vehicle</a></li>
# <li><a href="/insurance/">Get insurance</a></li>
# <li><a href="https://www.carpages.ca/blog/category/reviews/">Car reviews</a></li>
# <li><a href="https://www.carpages.ca/blog/used-car-buying-guide/">Used Car Buying Guide</a></li>
# </ul>
# </div>
# <div class="col-12 col-md-4">
# <h6 class="brand-face push-half--bottom">For Dealers</h6>
# <ul class="list--no-style push-none">
# <li>
# <a href="https://dealers.carpages.ca/dealerpage/" rel="nofollow">Advertise with us</a> </li>
# <li>
# <a class="ifx ai-c" href="https://dealers.carpages.ca/dealersite/" target="_blank"><span class="push-half--right">Discover DealerSite+</span>
# <span class="svg svg-xs"><svg enable-background="new 0 0 24 24" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><rect fill="none" height="24" width="24"></rect><path d="M9,6L9,6c0,0.56,0.45,1,1,1h5.59L4.7,17.89c-0.39,0.39-0.39,1.02,0,1.41h0c0.39,0.39,1.02,0.39,1.41,0L17,8.41V14 c0,0.55,0.45,1,1,1H18c0.55,0,1-0.45,1-1V6c0-0.55-0.45-1-1-1H10C9.45,5,9,5.45,9,6z"></path></svg></span></a> </li>
# <li>
# <a href="/account/login/" rel="nofollow">Account sign in</a> </li>
# </ul>
# </div>
# <div class="col-12 col-md-4">
# <h6 class="brand-face push-half--bottom">About Us</h6>
# <ul class="list--no-style push-none">
# <li>
# <a href="/help/contact/">Contact us</a> </li>
# <li>
# <a href="/blog/">Our Blog</a> </li>
# <li>
# <a class="ifx ai-c" href="https://jobs.carpages.ca/" rel="nofollow" target="_blank"><span class="push-half--right">Careers</span>
# <span class="svg svg-xs"><svg enable-background="new 0 0 24 24" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><rect fill="none" height="24" width="24"></rect><path d="M9,6L9,6c0,0.56,0.45,1,1,1h5.59L4.7,17.89c-0.39,0.39-0.39,1.02,0,1.41h0c0.39,0.39,1.02,0.39,1.41,0L17,8.41V14 c0,0.55,0.45,1,1,1H18c0.55,0,1-0.45,1-1V6c0-0.55-0.45-1-1-1H10C9.45,5,9,5.45,9,6z"></path></svg></span></a> </li>
# <li>
# <a href="/help/about/">About Carpages.ca</a> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-6 push-top flush-large grey">
# <span>Copyright © 2003-2022 Carpages.ca (div. of Autopath Technologies Inc.), All Rights Reserved.</span>
# <ul class="nav nav--spaced line-height--double">
# <li><a href="/help/privacy/">Privacy Policy</a></li>
# <li><a href="/help/terms/">Terms &amp; Conditions</a></li>
# </ul>
# <ul class="nav nav--spaced gamma push--top">
# <li>
# <a href="https://itunes.apple.com/ca/app/carpages.ca-used-cars-for/id616927030" rel="nofollow" target="_blank" title="iOS App">
# <i class="grey icon--apple"></i>
# </a>
# </li>
# <li>
# <a href="https://play.google.com/store/apps/details?id=ca.carpages.carpagesconsumer" rel="nofollow" target="_blank" title="Android App">
# <i class="grey icon--android"></i>
# </a>
# </li>
# <li>
# <a href="https://www.facebook.com/Carpages" rel="nofollow" target="_blank" title="Facebook">
# <i class="grey icon--facebook"></i>
# </a>
# </li>
# <li>
# <a href="https://twitter.com/carpages" rel="nofollow" target="_blank" title="Twitter">
# <i class="grey icon--twitter"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# <!-- End Main Footer -->
# <div class="ad-slot no-header ad-size--320x50 visible--small jam-adhesion-ad ad--banner--vdp"><div class="ad" id="jam_adAdhesion"></div><script>
#                googletag.cmd.push(function() {
#                    googletag.display("jam_adAdhesion");
#                });
#                </script></div>
# <!-- Scripts -->
# <script data-main="/js/primary/dist/search" src="/js/primary/dist/main.js?v=20220321" type="text/javascript"></script>
# <!-- End Scripts -->
# <!-- Dynamic Ad Activate -->
# <script>
#     CP.queue(function() {
#         globallyAccessibleNamespace.dynamicAd();
#     })
# </script>
# <!-- End Dynamic Ad Activate -->
# </body>
# </html>

# %%
# posting = soup.find_all('div',class_ = 'media soft push-none rule')
# len(posting)

# %%
df = pd.DataFrame({'Link':[''],'Name':[''],'Price':[''],'Color':['']})

# %%
# for post in posting:
#     link = post.find('a',class_ = "media__img media__img--thumb").get('href')
#     link_full = 'https://www.carpages.ca' + link
#     name = post.find('h4',class_ = 'hN').text.strip()
#     price = post.find('strong',class_ = 'delta').text.strip()
#     color = post.find_all('div',class_ = 'grey l-column l-column--small-6 l-column--medium-4')[1].text.strip()
#     df = df.append({'Link':link_full,'Name':name,'Price':price,'Color':color},ignore_index=True)

# %%
df
# Out:
#   Link Name Price Color
# 0

# %% [markdown]
# **Till Now we have grabbed all the cars from the 1st page**

# %%
# next_page = soup.find('a',class_ = 'nextprev').get('href')
# next_page_full = 'https://www.carpages.ca'+ next_page
# next_page_full

# %% [markdown]
# **To scrape first 10 page**

# %%
counter = 0
#This loop goes through the first 10 pages and grabs all the details of each posting
while counter < 10:
    
    #gets the HTML of all the postings on the page
    postings = soup.find_all('div', class_ = 'media soft push-none rule')

    #grabs all the details for each posting and adds it as a row to the dataframe
    for post in postings:
        link = post.find('a', class_ = 'media__img media__img--thumb').get('href')
        link_full = 'https://www.carpages.ca' +link
        name = post.find('h4', class_ = 'hN').text.strip()
        price = post.find('strong', class_ = 'delta').text.strip()
        color = post.find_all('div', class_ = 'grey l-column l-column--small-6 l-column--medium-4')[1].text.strip()
        df = df.append({'Link':link_full, 'Name':name, 'Price':price, 'Color':color}, ignore_index = True)
    
    #grabs the url of the next page
    next_page = soup.find('a', class_ = 'nextprev').get('href')
    next_page_full = 'https://www.carpages.ca'+ next_page
    #Imports the next pages HTML into python
    page = requests.get(next_page_full)
    soup = BeautifulSoup(page.text, 'lxml')
    counter += 1

# %%
df
# Out:
#                                                   Link  \
# 0
# 1    https://www.carpages.ca/used-cars/ontario/scar...
# 2    https://www.carpages.ca/used-cars/british-colu...
# 3    https://www.carpages.ca/used-cars/ontario/miss...
# 4    https://www.carpages.ca/used-cars/ontario/toro...
# ..                                                 ...
# 486  https://www.carpages.ca/used-cars/ontario/pert...
# 487  https://www.carpages.ca/used-cars/ontario/hami...
# 488  https://www.carpages.ca/used-cars/alberta/calg...
# 489  https://www.carpages.ca/used-cars/british-colu...
# 490  https://www.carpages.ca/used-cars/ontario/thun...
#
#                        Name    Price                      Color
# 0
# 1            2006 Acura RSX   $9,500                       Gray
# 2         2020 Ford Mustang  $41,999
# 3      2011 Volkswagen Golf   $5,200                      White
# 4       2017 Toyota Corolla  $20,699                       Grey
# ..                      ...      ...                        ...
# 486   2009 Dodge Challenger  $39,995                HEMI ORANGE
# 487        2004 Dodge Viper  $69,000                     Silver
# 488  2019 Mercedes-Benz C43  $65,900  designo Diamond White Met
# 489        2018 Honda Civic  $26,800                       Blue
# 490   2012 Chevrolet Camaro  $24,999                VICTORY RED
#
# [491 rows x 4 columns]

# %%
df.shape
# Out:
# (491, 4)
